# %%
import os
import sys
# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.feature_engineering import *

# %%
analysis = feature_engineering('../data/data.csv')

# %%
analysis.aggregate_features()
# Out:
#            CustomerId  Total_transaction_amount  Average_transaction_amount  \
# 3678   CustomerId_909                83451240.0                7.256630e+05
# 400   CustomerId_1535                60212748.0                8.601821e+06
# 2952  CustomerId_4878                50804960.0                2.478291e+05
# 3180  CustomerId_5155                29726020.0                2.456696e+05
# 2625  CustomerId_4453                29294460.0                5.424900e+05
# 888   CustomerId_2266                23768355.5                3.086799e+05
# 1020  CustomerId_2445                17743762.0                3.226139e+05
# 919   CustomerId_2303                13074000.0                1.188545e+06
# 121   CustomerId_1175                 8942702.5                3.710665e+04
# 222   CustomerId_1302                 7740285.0                4.300158e+05
# 3104  CustomerId_5054                 6848030.0                5.187902e+04
# ...

# %%
analysis.extract_features()
# Out:
#    Transaction_Hour  Transaction_Day  Transaction_Month  Transaction_Year
# 0                 2               15                 11              2018
# 1                 2               15                 11              2018
# 2                 2               15                 11              2018
# 3                 3               15                 11              2018
# 4                 3               15                 11              2018

# %%
analysis.label_encoding()
# Out:
#       ProductCategory  ProductCategory_encoded CurrencyCode  \
# 0             airtime                        0          UGX
# 1  financial_services                        2          UGX
# 2             airtime                        0          UGX
# 3        utility_bill                        8          UGX
# 4  financial_services                        2          UGX
#
#    CurrencyCode_encoded
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
#              Original  Encoded
# 0             airtime        0
# 1        data_bundles        1
# 2  financial_services        2
# 3              movies        3
# 4               other        4
#   Original  Encoded
# 0      UGX        0

# %%
analysis.normalize_numerical_feature()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 analysis.normalize_numerical_feature()
#
# File c:\Users\Ashis\Desktop\KAIM Program 2\week_6\scripts\feature_engineering.py:80, in feature_engineering.normalize_numerical_feature(self)
#      78 self.df['Standardized_Amount'] = scaler.fit_transform(self.df[['Amount']])
#      79 normalized_cols = ['Amount', 'Normalized_Amount', 'Standard_Amount']
# ---> 80 display(self.df[normalized_cols].head())
#
# File c:\Users\Ashis\Desktop\KAIM Program 2\week_6\week6\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...
