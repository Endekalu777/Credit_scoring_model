# %%
# Add the project root directory to sys.path
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.modeling import *

# %%
analysis = ModelSelectionAndTraining('../data/train_final.csv', '../data/test_final.csv')

# %% [markdown]
# # Model Selection and Evaluation for Classification Tasks

# %%
analysis.model_selection_and_training()
# Out:
# Training Logistic Regression...
# Cross-Validation Accuracy: 0.9901 ± 0.0037
# Model Logistic Regression saved as PKL file.
# Model: Logistic Regression
# Accuracy: 0.9875
# Precision: 0.9790
# Recall: 0.9964
# F1 Score: 0.9876
# ROC AUC: 0.9969
# ------------------------------
# Training Decision Tree...
# Cross-Validation Accuracy: 0.9557 ± 0.0151
# Model Decision Tree saved as PKL file.
# Model: Decision Tree
# Accuracy: 0.9456
# Precision: 0.9112
# Recall: 0.9875
# F1 Score: 0.9478
# ROC AUC: 0.9762
# ------------------------------
# Training Random Forest...
# Cross-Validation Accuracy: 0.9737 ± 0.0168
# Model Random Forest saved as PKL file.
# Model: Random Forest
# Accuracy: 0.9688
# Precision: 0.9614
# Recall: 0.9768
# F1 Score: 0.9691
# ROC AUC: 0.9925
# ------------------------------
