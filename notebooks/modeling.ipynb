# %%
# Add the project root directory to sys.path
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.modeling import *

# %%
analysis = ModelSelectionAndTraining('../data/train_final.csv', '../data/test_final.csv')

# %% [markdown]
# # Model Selection and Evaluation for Classification Tasks

# %%
analysis.model_selection_and_training()
# Out:
# Training Logistic Regression...
# Cross-Validation Accuracy: 0.9851 ± 0.0025
# 2024/10/07 12:46:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: Logistic Regression
# Accuracy: 0.9822
# Precision: 0.9839
# Recall: 0.9804
# F1 Score: 0.9821
# ROC AUC: 0.9981
# ------------------------------
# Training Decision Tree...
# Cross-Validation Accuracy: 0.9737 ± 0.0067
# 2024/10/07 12:46:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: Decision Tree
# Accuracy: 0.9750
# Precision: 0.9571
# Recall: 0.9947
# F1 Score: 0.9755
# ROC AUC: 0.9875
# ------------------------------
# Training Random Forest...
# Cross-Validation Accuracy: 0.9615 ± 0.0099
# 2024/10/07 12:46:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: Random Forest
# Accuracy: 0.9733
# Precision: 0.9801
# Recall: 0.9661
# F1 Score: 0.9731
# ROC AUC: 0.9938
# ------------------------------
