# %%
# Add the project root directory to sys.path
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.modeling import *

# %%
analysis = ModelSelectionAndTraining('../data/train_final.csv', '../data/test_final.csv')

# %% [markdown]
# # Model Selection and Evaluation for Classification Tasks

# %%
analysis.model_selection_and_training()
# Out:
# Training Logistic Regression...
# Cross-Validation Accuracy: 0.9905 ± 0.0034
# 2024/10/07 15:47:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: Logistic Regression
# Accuracy: 0.9875
# Precision: 0.9790
# Recall: 0.9964
# F1 Score: 0.9876
# ROC AUC: 0.9969
# ------------------------------
# Training Decision Tree...
# Cross-Validation Accuracy: 0.9626 ± 0.0166
# 2024/10/07 15:48:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: Decision Tree
# Accuracy: 0.9456
# Precision: 0.9112
# Recall: 0.9875
# F1 Score: 0.9478
# ROC AUC: 0.9762
# ------------------------------
# Training Random Forest...
# Cross-Validation Accuracy: 0.9626 ± 0.0251
# ...
