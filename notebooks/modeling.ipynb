# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.modeling import *

# %%
analysis = ModelSelectionAndTraining('../data/train_final.csv', '../data/test_final.csv')

# %%
analysis.model_selection_and_training()
# Out:
# Training Logistic Regression...
# Cross-Validation Accuracy: 0.9847 ± 0.0024
# Model: Logistic Regression
# Accuracy: 0.9822
# Precision: 0.9839
# Recall: 0.9804
# F1 Score: 0.9821
# ROC AUC: 0.9981
# ------------------------------
# Training Decision Tree...
# Cross-Validation Accuracy: 0.9729 ± 0.0062
# Model: Decision Tree
# Accuracy: 0.9750
# Precision: 0.9571
# Recall: 0.9947
# F1 Score: 0.9755
# ROC AUC: 0.9875
# ------------------------------
# Training Random Forest...
# Cross-Validation Accuracy: 0.9546 ± 0.0216
# Model: Random Forest
# Accuracy: 0.9635
# Precision: 0.9779
# Recall: 0.9483
# F1 Score: 0.9629
# ROC AUC: 0.9934
# ------------------------------
